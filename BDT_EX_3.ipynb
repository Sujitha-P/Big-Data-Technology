# %%
# ==============================
# STEP 1: Install Java & Hadoop
# ==============================
# !apt-get update -y
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Download Hadoop 3.3.6
# !wget -q https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz
# !mv hadoop-3.3.6 /usr/local/hadoop

# ==============================
# STEP 2: Setup Hadoop Env
# ==============================
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/usr/local/hadoop"
os.environ["PATH"] = f"{os.environ['HADOOP_HOME']}/bin:{os.environ['JAVA_HOME']}/bin:" + os.environ["PATH"]

# !hadoop version
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [343 B]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,827 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,858 kB]
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,595 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,450 kB]
# Get:17 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,138 kB]
# Fetched 20.3 MB in 4s (4,821 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /usr/local/hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
# !mkdir input_data

with open("input_data/input1.txt", "w") as f:
    f.write("Hadoop is an open-source framework used for processing large data\n")

with open("input_data/input2.txt", "w") as f:
    f.write("It distributes data across multiple nodes to enable faster computation\n")

# !cat input_data/*
# Out:
# Hadoop is an open-source framework used for processing large data
# It distributes data across multiple nodes to enable faster computation

# %%
# %%bash
# cat > mapper.py <<'EOF'
# #!/usr/bin/env python3
# import sys
#
# for line in sys.stdin:
#     line = line.strip()
#     for word in line.split():
#         print(f"{word}\t1")
# EOF
#
# cat > combiner.py <<'EOF'
# #!/usr/bin/env python3
# import sys
# from collections import defaultdict
#
# counts = defaultdict(int)
# for line in sys.stdin:
#     word, count = line.strip().split("\t")
#     counts[word] += int(count)
#
# for word, count in counts.items():
#     print(f"{word}\t{count}")
# EOF
#
# cat > reducer.py <<'EOF'
# #!/usr/bin/env python3
# import sys
#
# current_word = None
# current_count = 0
#
# for line in sys.stdin:
#     word, count = line.strip().split("\t")
#     count = int(count)
#
#     if current_word == word:
#         current_count += count
#     else:
#         if current_word:
#             print(f"{current_word}\t{current_count}")
#         current_word = word
#         current_count = count
#
# if current_word:
#     print(f"{current_word}\t{current_count}")
# EOF
#
# chmod +x mapper.py combiner.py reducer.py

# %%
# ==============================
# STEP 5: Run Hadoop Streaming Job
# ==============================
# !hadoop fs -rm -r -f input output

# Put input files into HDFS
# !hadoop fs -mkdir -p input
# !hadoop fs -put input_data/* input/

# Run Hadoop Streaming
# !hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-*.jar \
  -input input \
  -output output \
  -mapper mapper.py \
  -combiner combiner.py \
  -reducer reducer.py \
  -file mapper.py \
  -file combiner.py \
  -file reducer.py
# Out:
# 2025-11-14 16:51:01,374 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper.py, combiner.py, reducer.py] [] /tmp/streamjob8814433144072036210.jar tmpDir=null
# 2025-11-14 16:51:02,100 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2025-11-14 16:51:02,204 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2025-11-14 16:51:02,204 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2025-11-14 16:51:02,227 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-11-14 16:51:02,452 INFO mapred.FileInputFormat: Total input files to process : 2
# 2025-11-14 16:51:02,475 INFO mapreduce.JobSubmitter: number of splits:2
# 2025-11-14 16:51:02,659 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1236364078_0001
# 2025-11-14 16:51:02,659 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2025-11-14 16:51:03,050 INFO mapred.LocalDistributedCacheManager: Localized file:/content/mapper.py as file:/tmp/hadoop-root/mapred/local/job_local1236364078_0001_9b4603c3-a209-4190-9a7a-90c2b24edd76/mapper.py
# 2025-11-14 16:51:03,097 INFO mapred.LocalDistributedCacheManager: Localized file:/content/combiner.py as file:/tmp/hadoop-root/mapred/local/job_local1236364078_0001_bc4e1603-dc20-45dc-8b8b-c515648ded67/combiner.py
# 2025-11-14 16:51:03,098 INFO mapred.LocalDistributedCacheManager: Localized file:/content/reducer.py as file:/tmp/hadoop-root/mapred/local/job_local1236364078_0001_7911c1bf-4da7-4797-a201-360fc33d40a6/reducer.py
# 2025-11-14 16:51:03,290 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2025-11-14 16:51:03,293 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2025-11-14 16:51:03,295 INFO mapreduce.Job: Running job: job_local1236364078_0001
# 2025-11-14 16:51:03,299 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2025-11-14 16:51:03,396 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-11-14 16:51:03,396 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-11-14 16:51:03,442 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2025-11-14 16:51:03,447 INFO mapred.LocalJobRunner: Starting task: attempt_local1236364078_0001_m_000000_0
# 2025-11-14 16:51:03,484 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-11-14 16:51:03,484 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-11-14 16:51:03,511 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-11-14 16:51:03,524 INFO mapred.MapTask: Processing split: file:/content/input/input2.txt:0+71
# 2025-11-14 16:51:03,541 INFO mapred.MapTask: numReduceTasks: 1
# 2025-11-14 16:51:03,621 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-11-14 16:51:03,621 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-11-14 16:51:03,621 INFO mapred.MapTask: soft limit at 83886080
# 2025-11-14 16:51:03,621 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-11-14 16:51:03,621 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-11-14 16:51:03,627 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-11-14 16:51:03,633 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper.py]
# 2025-11-14 16:51:03,637 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2025-11-14 16:51:03,640 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2025-11-14 16:51:03,640 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2025-11-14 16:51:03,640 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2025-11-14 16:51:03,641 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2025-11-14 16:51:03,641 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2025-11-14 16:51:03,643 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2025-11-14 16:51:03,643 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2025-11-14 16:51:03,643 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2025-11-14 16:51:03,644 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2025-11-14 16:51:03,644 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2025-11-14 16:51:03,645 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2025-11-14 16:51:03,674 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-11-14 16:51:03,742 INFO streaming.PipeMapRed: Records R/W=1/1
# 2025-11-14 16:51:03,752 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-11-14 16:51:03,752 INFO streaming.PipeMapRed: mapRedFinished
# 2025-11-14 16:51:03,755 INFO mapred.LocalJobRunner:
# 2025-11-14 16:51:03,755 INFO mapred.MapTask: Starting flush of map output
# 2025-11-14 16:51:03,755 INFO mapred.MapTask: Spilling map output
# 2025-11-14 16:51:03,755 INFO mapred.MapTask: bufstart = 0; bufend = 91; bufvoid = 104857600
# 2025-11-14 16:51:03,755 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214360(104857440); length = 37/6553600
# 2025-11-14 16:51:03,772 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./combiner.py]
# 2025-11-14 16:51:03,777 INFO Configuration.deprecation: mapred.skip.map.auto.incr.proc.count is deprecated. Instead, use mapreduce.map.skip.proc-count.auto-incr
# 2025-11-14 16:51:03,797 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-11-14 16:51:03,798 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-11-14 16:51:03,868 INFO streaming.PipeMapRed: Records R/W=10/1
# 2025-11-14 16:51:03,879 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-11-14 16:51:03,879 INFO streaming.PipeMapRed: mapRedFinished
# 2025-11-14 16:51:03,879 INFO mapred.MapTask: Finished spill 0
# 2025-11-14 16:51:03,896 INFO mapred.Task: Task:attempt_local1236364078_0001_m_000000_0 is done. And is in the process of committing
# 2025-11-14 16:51:03,898 INFO mapred.LocalJobRunner: Records R/W=10/1
# 2025-11-14 16:51:03,898 INFO mapred.Task: Task 'attempt_local1236364078_0001_m_000000_0' done.
# 2025-11-14 16:51:03,908 INFO mapred.Task: Final Counters for attempt_local1236364078_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=1983
# 		FILE: Number of bytes written=646295
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=10
# 		Map output bytes=91
# 		Map output materialized bytes=117
# 		Input split bytes=82
# 		Combine input records=10
# 		Combine output records=10
# 		Spilled Records=10
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=315621376
# 	File Input Format Counters
# 		Bytes Read=87
# 2025-11-14 16:51:03,908 INFO mapred.LocalJobRunner: Finishing task: attempt_local1236364078_0001_m_000000_0
# 2025-11-14 16:51:03,908 INFO mapred.LocalJobRunner: Starting task: attempt_local1236364078_0001_m_000001_0
# 2025-11-14 16:51:03,909 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-11-14 16:51:03,910 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-11-14 16:51:03,910 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-11-14 16:51:03,912 INFO mapred.MapTask: Processing split: file:/content/input/input1.txt:0+66
# 2025-11-14 16:51:03,916 INFO mapred.MapTask: numReduceTasks: 1
# 2025-11-14 16:51:03,984 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-11-14 16:51:03,984 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-11-14 16:51:03,985 INFO mapred.MapTask: soft limit at 83886080
# 2025-11-14 16:51:03,985 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-11-14 16:51:03,985 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-11-14 16:51:03,987 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-11-14 16:51:03,992 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper.py]
# 2025-11-14 16:51:04,015 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-11-14 16:51:04,105 INFO streaming.PipeMapRed: Records R/W=1/1
# 2025-11-14 16:51:04,117 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-11-14 16:51:04,117 INFO streaming.PipeMapRed: mapRedFinished
# 2025-11-14 16:51:04,117 INFO mapred.LocalJobRunner:
# 2025-11-14 16:51:04,117 INFO mapred.MapTask: Starting flush of map output
# 2025-11-14 16:51:04,117 INFO mapred.MapTask: Spilling map output
# 2025-11-14 16:51:04,117 INFO mapred.MapTask: bufstart = 0; bufend = 86; bufvoid = 104857600
# 2025-11-14 16:51:04,117 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214360(104857440); length = 37/6553600
# 2025-11-14 16:51:04,123 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./combiner.py]
# 2025-11-14 16:51:04,138 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-11-14 16:51:04,138 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-11-14 16:51:04,217 INFO streaming.PipeMapRed: Records R/W=10/1
# 2025-11-14 16:51:04,229 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-11-14 16:51:04,229 INFO streaming.PipeMapRed: mapRedFinished
# 2025-11-14 16:51:04,229 INFO mapred.MapTask: Finished spill 0
# 2025-11-14 16:51:04,235 INFO mapred.Task: Task:attempt_local1236364078_0001_m_000001_0 is done. And is in the process of committing
# 2025-11-14 16:51:04,238 INFO mapred.LocalJobRunner: Records R/W=10/1
# 2025-11-14 16:51:04,239 INFO mapred.Task: Task 'attempt_local1236364078_0001_m_000001_0' done.
# 2025-11-14 16:51:04,240 INFO mapred.Task: Final Counters for attempt_local1236364078_0001_m_000001_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=2248
# 		FILE: Number of bytes written=646439
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=10
# 		Map output bytes=86
# 		Map output materialized bytes=112
# 		Input split bytes=82
# 		Combine input records=10
# 		Combine output records=10
# 		Spilled Records=10
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=421003264
# 	File Input Format Counters
# 		Bytes Read=82
# 2025-11-14 16:51:04,240 INFO mapred.LocalJobRunner: Finishing task: attempt_local1236364078_0001_m_000001_0
# 2025-11-14 16:51:04,240 INFO mapred.LocalJobRunner: map task executor complete.
# 2025-11-14 16:51:04,244 INFO mapred.LocalJobRunner: Starting task: attempt_local1236364078_0001_r_000000_0
# 2025-11-14 16:51:04,246 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2025-11-14 16:51:04,253 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-11-14 16:51:04,253 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-11-14 16:51:04,253 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-11-14 16:51:04,258 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@50a08924
# 2025-11-14 16:51:04,261 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-11-14 16:51:04,291 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2116865152, maxSingleShuffleLimit=529216288, mergeThreshold=1397131008, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2025-11-14 16:51:04,298 INFO reduce.EventFetcher: attempt_local1236364078_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2025-11-14 16:51:04,357 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1236364078_0001_m_000001_0 decomp: 108 len: 112 to MEMORY
# 2025-11-14 16:51:04,363 INFO reduce.InMemoryMapOutput: Read 108 bytes from map-output for attempt_local1236364078_0001_m_000001_0
# 2025-11-14 16:51:04,365 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 108, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->108
# 2025-11-14 16:51:04,373 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1236364078_0001_m_000000_0 decomp: 113 len: 117 to MEMORY
# 2025-11-14 16:51:04,374 INFO reduce.InMemoryMapOutput: Read 113 bytes from map-output for attempt_local1236364078_0001_m_000000_0
# 2025-11-14 16:51:04,375 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 113, inMemoryMapOutputs.size() -> 2, commitMemory -> 108, usedMemory ->221
# 2025-11-14 16:51:04,375 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2025-11-14 16:51:04,377 INFO mapred.LocalJobRunner: 2 / 2 copied.
# 2025-11-14 16:51:04,378 INFO reduce.MergeManagerImpl: finalMerge called with 2 in-memory map-outputs and 0 on-disk map-outputs
# 2025-11-14 16:51:04,388 INFO mapred.Merger: Merging 2 sorted segments
# 2025-11-14 16:51:04,389 INFO mapred.Merger: Down to the last merge-pass, with 2 segments left of total size: 207 bytes
# 2025-11-14 16:51:04,391 INFO reduce.MergeManagerImpl: Merged 2 segments, 221 bytes to disk to satisfy reduce memory limit
# 2025-11-14 16:51:04,392 INFO reduce.MergeManagerImpl: Merging 1 files, 223 bytes from disk
# 2025-11-14 16:51:04,393 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2025-11-14 16:51:04,393 INFO mapred.Merger: Merging 1 sorted segments
# 2025-11-14 16:51:04,395 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 210 bytes
# 2025-11-14 16:51:04,396 INFO mapred.LocalJobRunner: 2 / 2 copied.
# 2025-11-14 16:51:04,397 INFO mapreduce.Job: Job job_local1236364078_0001 running in uber mode : false
# 2025-11-14 16:51:04,400 INFO mapreduce.Job:  map 100% reduce 0%
# 2025-11-14 16:51:04,402 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reducer.py]
# 2025-11-14 16:51:04,405 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2025-11-14 16:51:04,408 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2025-11-14 16:51:04,425 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-11-14 16:51:04,426 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-11-14 16:51:04,488 INFO streaming.PipeMapRed: Records R/W=20/1
# 2025-11-14 16:51:04,499 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-11-14 16:51:04,500 INFO streaming.PipeMapRed: mapRedFinished
# 2025-11-14 16:51:04,501 INFO mapred.Task: Task:attempt_local1236364078_0001_r_000000_0 is done. And is in the process of committing
# 2025-11-14 16:51:04,502 INFO mapred.LocalJobRunner: 2 / 2 copied.
# 2025-11-14 16:51:04,502 INFO mapred.Task: Task attempt_local1236364078_0001_r_000000_0 is allowed to commit now
# 2025-11-14 16:51:04,503 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1236364078_0001_r_000000_0' to file:/content/output
# 2025-11-14 16:51:04,504 INFO mapred.LocalJobRunner: Records R/W=20/1 > reduce
# 2025-11-14 16:51:04,504 INFO mapred.Task: Task 'attempt_local1236364078_0001_r_000000_0' done.
# 2025-11-14 16:51:04,505 INFO mapred.Task: Final Counters for attempt_local1236364078_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=2764
# 		FILE: Number of bytes written=646844
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=19
# 		Reduce shuffle bytes=229
# 		Reduce input records=20
# 		Reduce output records=19
# 		Spilled Records=20
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=421003264
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=182
# 2025-11-14 16:51:04,505 INFO mapred.LocalJobRunner: Finishing task: attempt_local1236364078_0001_r_000000_0
# 2025-11-14 16:51:04,505 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2025-11-14 16:51:05,402 INFO mapreduce.Job:  map 100% reduce 100%
# 2025-11-14 16:51:05,403 INFO mapreduce.Job: Job job_local1236364078_0001 completed successfully
# 2025-11-14 16:51:05,412 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=6995
# 		FILE: Number of bytes written=1939578
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=2
# 		Map output records=20
# 		Map output bytes=177
# 		Map output materialized bytes=229
# 		Input split bytes=164
# 		Combine input records=20
# 		Combine output records=20
# 		Reduce input groups=19
# 		Reduce shuffle bytes=229
# 		Reduce input records=20
# 		Reduce output records=19
# 		Spilled Records=40
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=1157627904
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=169
# 	File Output Format Counters
# 		Bytes Written=182
# 2025-11-14 16:51:05,412 INFO streaming.StreamJob: Output directory: output

# %%
# !hadoop fs -cat output/part-00000
# Out:
# Hadoop	1
# It	1
# across	1
# an	1
# computation	1
# data	2
# distributes	1
# enable	1
# faster	1
# for	1
# framework	1
# is	1
# large	1
# multiple	1
# nodes	1
# open-source	1
# processing	1
# to	1
# used	1
